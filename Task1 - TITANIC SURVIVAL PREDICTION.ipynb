# %%
#Importing important libraries
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt  
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
#Loading the CSV file
df=pd.read_csv("titanic_cs.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.shape
# Out:
# (418, 12)

# %%
#finding the null values in the dataset
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#finding the null value of Age attribute
df.Age.isnull().sum()
# Out:
# 86

# %%
#Taking the median of the Age 
mnt=df.Age.median()
mnt
# Out:
# 27.0

# %%
#Replacing the null values with the median

df.Age.fillna(mnt,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df['Sex'].value_counts()
# Out:
# male      266
# female    152
# Name: Sex, dtype: int64

# %%
sns.pairplot(df, hue="Sex")
plt.show()

# %%
df['Survived'].value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
#Visualization
sns.boxplot(x='Survived', y='Pclass', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
sns.pairplot(df, hue="Survived")
plt.show()

# %%
sns.countplot(x="Survived", data=df)
plt.show()

# %%
sns.histplot(data=df, x="Age", hue="Survived", kde=True, palette="Set2")
plt.title("Survival Rate by Age")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(x="Survived", data=df, palette="Set1")
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.barplot(data=df, x="Sex", y="Survived", palette="Set2")
plt.title("Survival Rate by Gender")
plt.xlabel("Gender")
plt.ylabel("Survival Rate")
plt.show()

# %%
df.replace({'Sex':{'male':0,'female':1},'Embarked':{'s':0,'c':1,'Q':2}}, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                              Wirz, Mr. Albert    0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        2
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        2
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
#seperating  X and Y tO train and test the data 
#features=passengerId,Name,Ticket,Survived
#target=survived
X=df.drop(columns=["PassengerId","Name","Ticket","Survived"],axis=11)
Y=df["Survived"]

# %%
print(X)
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare Cabin Embarked
# 0         3    0  34.5      0      0    7.8292   NaN        2
# 1         3    1  47.0      1      0    7.0000   NaN        S
# 2         2    0  62.0      0      0    9.6875   NaN        2
# 3         3    0  27.0      0      0    8.6625   NaN        S
# 4         3    1  22.0      1      1   12.2875   NaN        S
# ..      ...  ...   ...    ...    ...       ...   ...      ...
# 413       3    0  27.0      0      0    8.0500   NaN        S
# 414       1    1  39.0      0      0  108.9000  C105        C
# 415       3    0  38.5      0      0    7.2500   NaN        S
# 416       3    0  27.0      0      0    8.0500   NaN        S
# 417       3    0  27.0      1      1   22.3583   NaN        C
#
# [418 rows x 8 columns]

# %%
print(Y)
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %%
#splitting the data into training and testing data 
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (418, 8) (334, 8) (84, 8)

# %%
model= LogisticRegression()
model
# Out:
# LogisticRegression()
